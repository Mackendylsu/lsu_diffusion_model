# %% [markdown]
# # A one-dimensional diffusion model

# %% [markdown]
# Here we develop a one-dimensional model of diffusion.
# It assumes a constant diffuisivity.
# It uses a regular grid.
# I has a step function for an initial condition.
# It has fixed boundary conditions.

# %% [markdown]
# The diffusion equation:
# $$ \frac{\partial C}{\partial t} = D\frac{\partial^2 C}{\partial x^2} $$

# %% [markdown]
# The discretized version of the diffusion equation we'll solve with out model:
#
# $$ C^{t+1}_x = C^t_x + {D \Delta t \over \Delta x^2} (C^t_{x+1} - 2C^t_x + C^t_{x-1}) $$

# %% [markdown]
# This is the FTCS scheme described in various textbooks. (Also Wikipedia.)

# %% [markdown]
# We'll use two libraries, Numpy (for arrays) and Matplotlib (for plots), that aren't a part of the core Python library.

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# Start by setting two fixed model parameters, the diffusivity and the size of the model domain.

# %%
D = 100
Lx = 300

# %% [markdown]
# Next, set up the model grid with a Numpy array.

# %%
dx = 0.5
x = np.arange(start=0, stop=Lx, step=dx)
nx = len(x)

# %% [markdown]
# Set up initial condition for the model.
# The concentration `C` is a step function with a high value on the left, a low value on the right, and the step at the center of the domain.

# %%
C = np.zeros_like(x)
C_left = 500
C_right = 0 
C [x <= Lx//2] = C_left
C [x > Lx//2] = C_right

# %% [markdown]
# Plot the initial concentration profile.

# %%
plt.figure()
plt.plot(x, C, "r")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Initial concentration profile")
# Out:
# Text(0.5, 1.0, 'Initial concentration profile')

# %% [markdown]
# Set the number of time steps in the model.
# Calculate a stable time step using a stability criterion.

# %%
nt = 5000
dt = 0.5 * dx**2 / D

# %%
dt
# Out:
# 0.00125

# %% [markdown]
# Loop over the time steps of the model, solving the diffusion equation using the FTCS scheme described above.
# Note the use of array operations on the concentration `C`. The boundary conditions remain fixed in each time step.

# %%
for t in range(0, nt):
	C[1:-1] += D * dt / dx ** 2 * (C[:-2] - 2*C[1:-1] + C[2:])

# %% [markdown]
# Plot the result.

# %%
plt.figure()
plt.plot(x, C, "b")
plt.xlabel("x")
plt.ylabel("C")
plt.title("Final concentration profile")
# Out:
# Text(0.5, 1.0, 'Final concentration profile')
